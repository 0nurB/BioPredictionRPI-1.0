# %% [markdown]
# #**Installing dependencies and package**

# %%
# !git clone https://github.com/0nurB/BioPredictionRPI-1.0.git BioPredictionRPI
# Out:
# Cloning into 'BioPredictionRPI'...
# Updating files:  12% (46/359)
# Updating files:  13% (47/359)
# Updating files:  14% (51/359)
# Updating files:  15% (54/359)
# Updating files:  16% (58/359)
# Updating files:  17% (62/359)
# Updating files:  18% (65/359)
# Updating files:  19% (69/359)
# Updating files:  20% (72/359)
# Updating files:  21% (76/359)
# Updating files:  22% (79/359)
# Updating files:  23% (83/359)
# Updating files:  24% (87/359)
# Updating files:  25% (90/359)
# Updating files:  26% (94/359)
# Updating files:  27% (97/359)
# Updating files:  28% (101/359)
# Updating files:  29% (105/359)
# Updating files:  30% (108/359)
# Updating files:  31% (112/359)
# Updating files:  32% (115/359)
# Updating files:  33% (119/359)
# Updating files:  34% (123/359)
# Updating files:  35% (126/359)
# Updating files:  36% (130/359)
# Updating files:  37% (133/359)
# Updating files:  38% (137/359)
# Updating files:  39% (141/359)
# Updating files:  40% (144/359)
# ...

# %%
# %cd BioPredictionRPI/
# Out:
# C:\Users\Bruno Rafael\Downloads\BioPredictionRPI

# %%
# !git submodule init
# Out:
# Submodule 'MathFeature' (https://github.com/Bonidia/MathFeature) registered for path 'MathFeature'

# %%
# !git submodule update
# Out:
# Submodule path 'MathFeature': checked out '23499bbf550a35aa604c047077ce26f05704b28a'
# Cloning into 'C:/Users/Bruno Rafael/Downloads/BioPredictionRPI/MathFeature'...

# %%
# !wget https://repo.anaconda.com/miniconda/Miniconda3-latest-Linux-x86_64.sh
# !chmod +x Miniconda3-latest-Linux-x86_64.sh
# !bash Miniconda3-latest-Linux-x86_64.sh
# Out:
# 'wget' is not recognized as an internal or external command,
# operable program or batch file.
# 'chmod' is not recognized as an internal or external command,
# operable program or batch file.
# 'bash' is not recognized as an internal or external command,
# operable program or batch file.

# %%
# !export PATH=~/miniconda3/bin:$PATH
# Out:
# 'export' is not recognized as an internal or external command,
# operable program or batch file.

# %%
# !/root/miniconda3/bin/conda init
# Out:
# The system cannot find the path specified.

# %%
# !/root/miniconda3/bin/conda create --name bioprediction-rpi python=3.11.5
# Out:
# The system cannot find the path specified.

# %%
# !/root/miniconda3/bin/activate bioprediction-rpi
# Out:
# The system cannot find the path specified.

# %%
# !pip install -r requeriments.txt
# Out:
# ...
# ERROR: Could not find a version that satisfies the requirement dgl==2.1.0 (from versions: 0.1.2, 0.1.3, 1.1.0, 1.1.1, 1.1.2, 2.0.0)
# ERROR: No matching distribution found for dgl==2.1.0

# %% [markdown]
# #**How to use**

# %%
# !python BioPrediction.py -input_interactions_train datasets/exp_1/RPI369/RPI369_pairs.csv -sequences_dictionary_protein datasets/exp_1/RPI369/RPI369_protein_seq.fa -sequences_dictionary_rna datasets/exp_1/RPI369/RPI369_dna_seq.fa -output exp_369_2
# Out:
# input_interactions_train - datasets/exp_1/RPI369/RPI369_pairs.csv: Found File
# C:\Users\Bruno Rafael\anaconda3\Lib\site-packages\sklearn\base.py:1474: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   return fit_method(estimator, *args, **kwargs)
# C:\Users\Bruno Rafael\anaconda3\Lib\site-packages\sklearn\base.py:1474: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   return fit_method(estimator, *args, **kwargs)
# C:\Users\Bruno Rafael\anaconda3\Lib\site-packages\sklearn\base.py:1474: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   return fit_method(estimator, *args, **kwargs)
# ...
